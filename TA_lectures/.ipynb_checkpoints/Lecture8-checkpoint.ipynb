# %% [markdown]
# ## TA Lecture 8

# %% [markdown]
# ### Working with Dummy Variables

# %%
data(Wage, package="ISLR")
head(Wage)
# Out:
#        year age maritl           race     education       region
# 231655 2006 18  1. Never Married 1. White 1. < HS Grad    2. Middle Atlantic
# 86582  2004 24  1. Never Married 1. White 4. College Grad 2. Middle Atlantic
# 161300 2003 45  2. Married       1. White 3. Some College 2. Middle Atlantic
# 155159 2003 43  2. Married       3. Asian 4. College Grad 2. Middle Atlantic
# 11443  2005 50  4. Divorced      1. White 2. HS Grad      2. Middle Atlantic
# 376662 2008 54  2. Married       1. White 4. College Grad 2. Middle Atlantic
#        jobclass       health         health_ins logwage  wage
# 231655 1. Industrial  1. <=Good      2. No      4.318063  75.04315
# 86582  2. Information 2. >=Very Good 2. No      4.255273  70.47602
# 161300 1. Industrial  1. <=Good      1. Yes     4.875061 130.98218
# 155159 2. Information 2. >=Very Good 1. Yes     5.041393 154.68529
# 11443  2. Information 1. <=Good      1. Yes     4.318063  75.04315
# ...

# %% [markdown]
# - We want to preduct log-wage using available information;
# - How should we pass dummy variables to the functions?

# %%
### Transform the matrix

new_X <- model.matrix(~. -1, data = Wage[, c(1:9)])
head(new_X)
# Out:
#        year age maritl1. Never Married maritl2. Married maritl3. Widowed
# 231655 2006 18  1                      0                0
# 86582  2004 24  1                      0                0
# 161300 2003 45  0                      1                0
# 155159 2003 43  0                      1                0
# 11443  2005 50  0                      0                0
# 376662 2008 54  0                      1                0
#        maritl4. Divorced maritl5. Separated race2. Black race3. Asian
# 231655 0                 0                  0            0
# 86582  0                 0                  0            0
# 161300 0                 0                  0            0
# 155159 0                 0                  0            1
# 11443  1                 0                  0            0
# 376662 0                 0                  0            0
#        race4. Other ⋯ region3. East North Central region4. West North Central
# ...

# %% [markdown]
# What happened?
#
# - We transformed the matrix into a set of 0/1 dummy variables. Now every component is numeric!

# %%
### Run lasso and ridge regression 
library(glmnet)
my_lasso <- cv.glmnet(y = Wage$logwage, x = as.matrix(new_X), alpha = 1)
my_ridge <- cv.glmnet(y = Wage$logwage, x = as.matrix(new_X), alpha = 0)
plot(my_lasso)
plot(my_ridge)
# Out:
# plot without title
# plot without title

# %%
## Look at the coefficients
print(cbind(coef(my_lasso), coef(my_ridge)))
# Out:
# 26 x 2 sparse Matrix of class "dgCMatrix"
#                                        1             1
# (Intercept)                 -6.959063142 -15.928284159
# year                         0.005696117   0.010165265
# age                          0.001626528   0.002391039
# maritl1. Never Married      -0.052507494  -0.078642181
# maritl2. Married             0.093347734   0.072897638
# maritl3. Widowed             .            -0.033248295
# maritl4. Divorced            .            -0.032778551
# maritl5. Separated           .             0.002316107
# race2. Black                 .            -0.040281803
# race3. Asian                 .            -0.005349413
# race4. Other                 .            -0.080775406
# education2. HS Grad         -0.006113751  -0.045786266
# education3. Some College     0.047397462   0.038449713
# education4. College Grad     0.156886064   0.121009834
# education5. Advanced Degree  0.304547070   0.241396001
# ...

# %%
## Interacting dummy variables 

X_with_interactions <- cbind(new_X, new_X[, 3:7]*new_X[,8], new_X[, 3:7]*new_X[,9], new_X[, 3:7]*new_X[,10])
head(X_with_interactions)
# Out:
#        year age maritl1. Never Married maritl2. Married maritl3. Widowed
# 231655 2006 18  1                      0                0
# 86582  2004 24  1                      0                0
# 161300 2003 45  0                      1                0
# 155159 2003 43  0                      1                0
# 11443  2005 50  0                      0                0
# 376662 2008 54  0                      1                0
#        maritl4. Divorced maritl5. Separated race2. Black race3. Asian
# 231655 0                 0                  0            0
# 86582  0                 0                  0            0
# 161300 0                 0                  0            0
# 155159 0                 0                  0            1
# 11443  1                 0                  0            0
# 376662 0                 0                  0            0
#        race4. Other ⋯ maritl1. Never Married maritl2. Married maritl3. Widowed
# ...

# %%
## Run a regression here 
my_lasso <- cv.glmnet(y = Wage$logwage, x = as.matrix(X_with_interactions), alpha = 1)
coef(my_lasso)
# Out:
# 41 x 1 sparse Matrix of class "dgCMatrix"
#                                        1
# (Intercept)                 -5.613325798
# year                         0.005033035
# age                          0.001546128
# maritl1. Never Married      -0.051305511
# maritl2. Married             0.092330630
# maritl3. Widowed             .
# maritl4. Divorced            .
# maritl5. Separated           .
# race2. Black                 .
# race3. Asian                 .
# race4. Other                 .
# education2. HS Grad         -0.014724685
# education3. Some College     0.034295729
# education4. College Grad     0.144488840
# education5. Advanced Degree  0.291985010
# region2. Middle Atlantic     .
# region3. East North Central  .
# region4. West North Central  .
# region5. South Atlantic      .
# region6. East South Central  .
# region7. West South Central  .
# region8. Mountain            .
# region9. Pacific             .
# jobclass2. Information       0.015395361
# ...

# %%
## Use gam 
library(gam)
gam1 <- gam(Wage$logwage ~ ., data = new_X)
# Out:
# Error in model.frame.default(formula = Wage$logwage ~ year + age + `maritl1. Never Married` + : 'data' must be a data.frame, not a matrix or an array
# Traceback:
#
# 1. gam(Wage$logwage ~ ., data = new_X)
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = Wage$logwage ~ year + age + `maritl1. Never Married` +
#  .     `maritl2. Married` + `maritl3. Widowed` + `maritl4. Divorced` +
#  .     `maritl5. Separated` + `race2. Black` + `race3. Asian` +
#  .     `race4. Other` + `education2. HS Grad` + `education3. Some College` +
#  .     `education4. College Grad` + `education5. Advanced Degree` +
#  .     `region2. Middle Atlantic` + `region3. East North Central` +
#  .     `region4. West North Central` + `region5. South Atlantic` +
#  .     `region6. East South Central` + `region7. West South Central` +
#  .     `region8. Mountain` + `region9. Pacific` + `jobclass2. Information` +
# ...

# %%
## This are errors that often occurr
## We need to transform X in a data frame 

library(gam)
gam1 <- gam(Wage$logwage ~ ., data = as.data.frame(new_X))
summary(gam1)
# Out:
# Call: gam(formula = Wage$logwage ~ ., data = as.data.frame(new_X))
# Deviance Residuals:
#       Min        1Q    Median        3Q       Max
# -1.523795 -0.146518  0.003207  0.155840  1.244222
#
# (Dispersion Parameter for gaussian family taken to be 0.0777)
#
#     Null Deviance: 371.0659 on 2999 degrees of freedom
# Residual Deviance: 231.8452 on 2983 degrees of freedom
# AIC: 868.7385
#
# Number of Local Scoring Iterations: 2
#
# Anova for Parametric Effects
#                                 Df  Sum Sq Mean Sq  F value    Pr(>F)
# year                             1   2.157   2.157  27.7496 1.479e-07 ***
# age                              1  17.171  17.171 220.9340 < 2.2e-16 ***
# `maritl1. Never Married`         1  13.757  13.757 177.0026 < 2.2e-16 ***
# `maritl2. Married`               1   5.186   5.186  66.7264 4.555e-16 ***
# `maritl3. Widowed`               1   0.007   0.007   0.0850  0.770623
# `maritl4. Divorced`              1   0.001   0.001   0.0090  0.924614
# ...

# %%
### Examples with different data 


data(Boston, package="MASS")



### From previous lecture 

### Run different polynomials using a for loop 
s3 <- list()
for (i in c(2,3,8)) {  
  pol <- lm(nox ~ poly(dis,i), data=Boston)
 s3[[i]] <- pol 
  }


## Plot the results 
plot(cbind(Boston$dis, Boston$nox), xlab="Distance from Emp.Center", ylab= "Nitrogen Dioxide", main ="Boston Data", col="green", cex=0.7,
     pch=19)

lines(predict(s3[[2]])[order(dis)]~sort(dis), data=Boston, lwd=2, col='blue', lty="dotted")
lines(predict(s3[[3]])[order(dis)]~sort(dis), data=Boston, col="red", lwd=2, lty="dotted")
lines(predict(s3[[8]])[order(dis)]~sort(dis), data=Boston, col="black", lwd=2, lty="dotted")
## Add a legend
legend("topright", legend=c("2 degree","3 degree", "8 degree"),        
    cex=0.7, lwd=1, col=c("blue","red", "black"))
# Out:
# Plot with title “Boston Data”

# %%
### Use gam

gam_boston_data <- gam(nox ~ ., data = Boston)
summary(gam_boston_data)
coef(gam_boston_data)
# Out:
# Call: gam(formula = nox ~ ., data = Boston)
# Deviance Residuals:
#       Min        1Q    Median        3Q       Max
# -0.120257 -0.034766 -0.003939  0.031042  0.182760
#
# (Dispersion Parameter for gaussian family taken to be 0.003)
#
#     Null Deviance: 6.781 on 505 degrees of freedom
# Residual Deviance: 1.4783 on 492 degrees of freedom
# AIC: -1486.862
#
# Number of Local Scoring Iterations: 2
#
# Anova for Parametric Effects
#            Df  Sum Sq Mean Sq  F value    Pr(>F)
# crim        1 1.20170 1.20170 399.9375 < 2.2e-16 ***
# zn          1 1.31977 1.31977 439.2314 < 2.2e-16 ***
# indus       1 1.64929 1.64929 548.9003 < 2.2e-16 ***
# chas        1 0.01911 0.01911   6.3587   0.01200 *
# rm          1 0.00190 0.00190   0.6325   0.42684
# age         1 0.48298 0.48298 160.7403 < 2.2e-16 ***
# dis         1 0.22667 0.22667  75.4371 < 2.2e-16 ***
# rad         1 0.11918 0.11918  39.6654 6.690e-10 ***
# tax         1 0.00529 0.00529   1.7600   0.18523
# ...

# %%
## Use splines 

gam_boston_data_splines <- gam(nox ~ s(dis, df=4, spar=0.1) + crim, data = Boston)
summary(gam_boston_data_splines)
coef(gam_boston_data_splines)
# Out:
# Call: gam(formula = nox ~ s(dis, df = 4, spar = 0.1) + crim, data = Boston)
# Deviance Residuals:
#       Min        1Q    Median        3Q       Max
# -0.123542 -0.041087 -0.008862  0.021698  0.196782
#
# (Dispersion Parameter for gaussian family taken to be 0.0038)
#
#     Null Deviance: 6.781 on 505 degrees of freedom
# Residual Deviance: 1.9015 on 499.9999 degrees of freedom
# AIC: -1375.48
#
# Number of Local Scoring Iterations: 2
#
# Anova for Parametric Effects
#                             Df Sum Sq Mean Sq   F value Pr(>F)
# s(dis, df = 4, spar = 0.1)   1 4.0124  4.0124 1055.0510 <2e-16 ***
# crim                         1 0.0025  0.0025    0.6458  0.422
# Residuals                  500 1.9015  0.0038
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Anova for Nonparametric Effects
#                            Npar Df Npar F     Pr(F)
# (Intercept)
# s(dis, df = 4, spar = 0.1)       3 64.452 < 2.2e-16 ***
# crim
# ---
# ...

# %% [markdown]
# - Remember: the selection of tuning parameters must be performed via cross validation.

# %%
## Alternative code to run splies 

## Run a cubic spline (see Lecture 7 for cross validation)
reg.ns <- lm(Boston$nox ~ ns(x=dis, df=3), data=Boston)

# %% [markdown]
# ### Take Home Final: Out of Sample Predictions

# %%
data <- read.table('./data/data_tr.txt', head = T)
head(data)
# Out:
#   X tw     ira  e401 nifa  inc   hmort hval   hequity educ male twoearn nohs hs
# 1 1  53550    0 0      100 28146 60150  69000   8850  12   0    0       0    1
# 2 2 124635    0 0    61010 32634 20000  78000  58000  16   0    0       0    0
# 3 3 192949 1800 0     7549 52206 15900 200000 184100  11   1    1       1    0
# 4 4   -513    0 0     2487 45252     0      0      0  15   0    1       0    0
# 5 5 212087    0 0    10625 33126 90000 300000 210000  12   0    0       0    1
# 6 6  24400    0 0     9000 76860 99600 120000  20400  15   0    1       0    0
#   smcol col age fsize marr
# 1 0     0   31  5     1
# 2 0     1   52  5     0
# 3 0     0   50  3     1
# 4 1     0   28  4     1
# 5 0     0   42  3     0
# 6 1     0   49  6     1

# %%
### Use arbitrary transformations 


tranformed_data <- cbind(data, data$male*data$marr)
head(tranformed_data)
# Out:
#   X tw     ira  e401 nifa  inc   hmort hval   hequity educ male twoearn nohs hs
# 1 1  53550    0 0      100 28146 60150  69000   8850  12   0    0       0    1
# 2 2 124635    0 0    61010 32634 20000  78000  58000  16   0    0       0    0
# 3 3 192949 1800 0     7549 52206 15900 200000 184100  11   1    1       1    0
# 4 4   -513    0 0     2487 45252     0      0      0  15   0    1       0    0
# 5 5 212087    0 0    10625 33126 90000 300000 210000  12   0    0       0    1
# 6 6  24400    0 0     9000 76860 99600 120000  20400  15   0    1       0    0
#   smcol col age fsize marr data$male * data$marr
# 1 0     0   31  5     1    0
# 2 0     1   52  5     0    0
# 3 0     0   50  3     1    1
# 4 1     0   28  4     1    0
# 5 0     0   42  3     0    0
# 6 1     0   49  6     1    0

# %%
### We added an interaction component in the new data 

## We now run our favorite specification (e.g., lasso)

my_model <- cv.glmnet(y = data$tw, x = as.matrix(tranformed_data[, c(3:20)]))

### We now want to make the predictions 

data_test <- read.table('./data/X_test_final_project.txt', head = T)
### Predict using this data

## Step 1. Apply the same transformation to the test data that you used on the training data
tranformed_data_test <- cbind(data_test, data_test$male*data_test$marr)
head(tranformed_data_test)
# Out:
#   ira   e401 nifa  inc   hmort hval   hequity educ male twoearn nohs hs smcol
# 1     0 0      100 40323     0      0      0  12   1    1       0    1  0
# 2     0 0        0 30000     0      0      0  14   0    0       0    0  1
# 3 34000 0     1400 85086   235  12000  11765  12   1    1       0    1  0
# 4     0 0     1400 32208     0      0      0  13   0    1       0    0  1
# 5     0 0    53698 42084 52000 250000 198000  16   1    0       0    0  0
# 6     0 0     1300 35100     0      0      0  12   0    0       0    1  0
#   col age fsize marr data_test$male * data_test$marr
# 1 0   25  3     1    1
# 2 0   30  2     1    0
# 3 0   42  4     1    1
# 4 0   35  2     1    0
# 5 1   42  1     0    0
# 6 0   61  5     0    0

# %%
## Step 2. make your prediction

my_predictions <- predict(my_model, newx = as.matrix(tranformed_data_test[, c(1:18)]))
head(my_predictions)
# Out:
#   1
# 1  12927.65
# 2  11625.11
# 3  70066.26
# 4  13215.73
# 5 262612.65
# 6  13458.81

# %%
## Step 3. 
## Control that the length is correct! 

length(my_predictions)
dim(data_test)
# Out:
# [1] 1982
# [1] 1982   17

# %%
## Save your predictions

write.table(my_predictions, file = 'my_predictions.txt')

## report the txt in your submission!!!

# %%
### Remember: for some model the predict function takes newdata as imput 

## E.g., suppose we consider the model 
my_model <- lm(data$tw ~ ., data = tranformed_data[, c(3:20)])

## Then the predictions must be stored as 
my_predictions <- predict(my_model, newdata = tranformed_data_test[, c(1:18)])
# Out:
# Error in eval(predvars, data, env): object 'data$male * data$marr' not found
# Traceback:
#
# 1. predict(my_model, newdata = tranformed_data_test[, c(1:18)])
# 2. predict.lm(my_model, newdata = tranformed_data_test[, c(1:18)])
# 3. model.frame(Terms, newdata, na.action = na.action, xlev = object$xlevels)
# 4. model.frame.default(Terms, newdata, na.action = na.action, xlev = object$xlevels)
# 5. eval(predvars, data, env)
# 6. eval(predvars, data, env)

# %%
## What happened? Error in naming your variables 
## What to do? 

my_X <- tranformed_data[, c(3:20)]
names(my_X) <- paste0('V', c(1:dim(my_X)[2]))

## E.g., suppose we consider the model 
my_model <- lm(data$tw ~ ., data = my_X)


my_X_test <- tranformed_data_test[, c(1:18)]
names(my_X_test) <- paste0('V', c(1:dim(my_X_test)[2]))


## Then the predictions must be stored as 
my_predictions <- predict(my_model, newdata = my_X_test)
# Out:
# Warning message in predict.lm(my_model, newdata = my_X_test):
# “prediction from a rank-deficient fit may be misleading”
